# %%
# %load_ext autoreload
# %autoreload 2
import random
import copy

import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F

from util import view_10
from data import fetch_dataset, data_to_tensor, iid_partition_loader, noniid_partition_loader
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# set random seeds
np.random.seed(0)
torch.manual_seed(0)
random.seed(0)

# set device
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print("| using device:", device)
# Out:
# | using device: cpu

# %%
# hyperparams
bsz = 10

# %% [markdown]
# ## Data

# %%
import torchvision
transform = torchvision.transforms.Compose([
        torchvision.transforms.ToTensor(),
        torchvision.transforms.Normalize((0.1307,), (0.3081,))
    ])

# %%
train_data, test_data = fetch_dataset(transform)

test_loader = torch.utils.data.DataLoader(test_data, batch_size = 1000, shuffle=False) # inference bsz=1000
debug_loader = torch.utils.data.DataLoader(train_data, bsz)
img, label = next(iter(debug_loader))
view_10(img, label)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:09<00:00, 1095332.31it/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 355808.44it/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 2077237.25it/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 1193343.07it/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw

# %%
#replace labels in specified datasets base_class -> target_class
#and increase their frequency in the dataset
def poisonDataLoader(dataloader_list, base_class = 7, target_class = 1, increaseFrequency=False):
    example_base_image=None
    for client in dataloader_list:
      for idx in client.dataset.indices:
        if torch.equal(client.dataset.dataset.targets[idx], torch.tensor(base_class)):
          client.dataset.dataset.targets[idx] = torch.tensor(target_class) 
          example_base_image=client.dataset.dataset.data[idx]
        elif increaseFrequency and example_base_image != None:
          client.dataset.dataset.targets[idx] = torch.tensor(target_class) 
          client.dataset.dataset.data[idx] = example_base_image

# %%
# get client dataloaders
iid_client_train_loader = iid_partition_loader(train_data, bsz = bsz)
# noniid_client_train_loader = noniid_partition_loader(train_data, bsz = bsz)

# %% [markdown]
# ## Models

# %%
# define cnn
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, 5) 
        self.conv2 = nn.Conv2d(32, 64, 5)
        self.fc = nn.Linear(1024, 512)
        self.out = nn.Linear(512, 10)

    def forward(self, x):
        x = F.max_pool2d(self.conv1(x), 2, 2) # [B x 32 x 12 x 12]
        x = F.max_pool2d(self.conv2(x), 2, 2) # [B x 64 x 4 x 4]
        x = x.flatten(1) # [B x 1024]
        x = F.relu(self.fc(x)) # [B x 512]
        x = self.out(x) # [B x 10]
        return x

print(CNN())
# Out:
# CNN(
#   (conv1): Conv2d(1, 32, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1))
#   (fc): Linear(in_features=1024, out_features=512, bias=True)
#   (out): Linear(in_features=512, out_features=10, bias=True)
# )

# %% [markdown]
# ## Training

# %%
criterion = nn.CrossEntropyLoss()
#Validate model against specified dataloader
def validate(model, dataloader):
    model = model.to(device)
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for (t, (x,y)) in enumerate(dataloader):
            x = x.to(device)
            y = y.to(device)
            out = model(x)
            correct += torch.sum(torch.argmax(out, dim=1) == y).item()
            total += x.shape[0]
    return correct/total

def validate_poisons(model, dataloader, target_class, base_class): # how many examples in base class became target class?
    model = model.to(device)
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for (t, (x,y)) in enumerate(dataloader):
                x = x.to(device)
                y = y.to(device)
                out = model(x)
                predictions = torch.argmax(out, dim=1)
                for i, label in enumerate(y):
                     if label == base_class:
                          total+=1
                          correct += 1 if predictions[i] == target_class else 0
                # correct += torch.sum(predictions == y).item()
                # total += torch.sum(y == base_class).item()
    return correct/total

# %%
def train_client(id, client_loader, global_model, num_local_epochs, lr):
    local_model = copy.deepcopy(global_model)
    local_model = local_model.to(device)
    local_model.train()
    optimizer = torch.optim.SGD(local_model.parameters(), lr=lr)

    for epoch in range(num_local_epochs):
        for (i, (x,y)) in enumerate(client_loader):
            x = x.to(device)
            y = y.to(device)
            optimizer.zero_grad()
            out = local_model(x)
            loss = criterion(out, y)
            loss.backward()
            optimizer.step()

    return local_model

def running_model_avg(current, next, scale):
    if current == None:
        current = next
        for key in current:
            current[key] = current[key] * scale
    else:
        for key in current:
            current[key] = current[key] + (next[key] * scale)
    return current

# %%
# JUST ADDED FOR MEDIAN

def robust_aggregate_median(local_state_dicts):
    """
    Coordinate-wise median aggregation over a list of state_dicts.
    Each entry in local_state_dicts is model.state_dict().
    """
    assert len(local_state_dicts) > 0, "Need at least one local model to aggregate."

    agg_state = {}
    keys = local_state_dicts[0].keys()

    for k in keys:
        stacked = torch.stack(
            [sd[k].detach().cpu() for sd in local_state_dicts],
            dim=0  # [num_clients, ...]
        )
        median_param = stacked.median(dim=0).values
        agg_state[k] = median_param

    return agg_state

# %%
mse_criterion=nn.MSELoss()
cross_criterion=nn.CrossEntropyLoss()
def train_poisoned_model(poisons, global_model, num_local_epochs, lr, local_loss_weight = 0.85):
    local_model = copy.deepcopy(global_model)
    local_model = local_model.to(device)
    local_model.train()
    optimizer = torch.optim.SGD(local_model.parameters(), lr=lr)
    global_model_list =  nn.utils.parameters_to_vector(global_model.parameters()).clone().detach()
    global_model_list = global_model_list.flatten()

    for epoch in range(num_local_epochs):
        for (i, (x,y)) in enumerate(poisons):
            x = x.to(device)
            y = y.to(device)
            optimizer.zero_grad()
            out = local_model(x)
            local_model_list= nn.utils.parameters_to_vector(local_model.parameters()).clone().detach()
            local_model_list = local_model_list.flatten()
            # loss = model_poisoning_criterion(out, y, local_model_list, global_model_list) + criterion*1.5
            mse_loss = mse_criterion(local_model_list,global_model_list) * (1-local_loss_weight)
            cross_loss = cross_criterion(out, y) * local_loss_weight
            loss = mse_loss + cross_loss
            loss.backward()
            optimizer.step()
    #Scale up weights a bit to overcome averaging aggregation. We can apply this trick to our other attacks
    with torch.no_grad():
        for param in local_model.parameters():
            param *= 2.5 # 3 is nice but might overflow later
    return local_model

# %%
# model poisoning attack (i.e. calculate the ideal model to minimize poison loss and l2 dist from global model),
# or simple label-flip attack on data
def fed_avg_experiment(
    global_model,
    num_clients_per_round,
    num_local_epochs,
    lr,
    client_train_loader,
    max_rounds,
    filename,
    modelPoisonAttack=False,
    base_class=7,
    target_class=1,
    defense=None,       # when you want to add defense - median or none
):
    if modelPoisonAttack:
        print("Using constrain-and-scale attack + upsampling base class images")
    else:
        print("Using basic label flipping without modifying client images")
    round_accuracy = []
    poison_round_accuracy = []
    num_clients = len(client_train_loader)
    attacker_id = num_clients - 1 if modelPoisonAttack else None
    # One-time poisoning of training data per mode
    if not modelPoisonAttack:   # basic label flip on clients 0-5
        poisonDataLoader(
            [iid_client_train_loader[x] for x in range(0, 6)],
            base_class,
            target_class,
            increaseFrequency=False
        )
        img, label = next(iter(iid_client_train_loader[0]))
        view_10(img, label)
    else:
        # last client is the attacker for model poisoning
        poisonDataLoader(
            [client_train_loader[attacker_id]],
            base_class,
            target_class,
            increaseFrequency=True
        )
        img, label = next(iter(iid_client_train_loader[attacker_id]))
        view_10(img, label)
    for t in range(max_rounds):
        print("starting round {}".format(t))

        # choose honest clients
        if modelPoisonAttack:
            honest_pool = np.arange(num_clients - 1)  # exclude attacker
            num_honest = num_clients_per_round - 1
        else:
            honest_pool = np.arange(num_clients)
            num_honest = num_clients_per_round

        clients = np.random.choice(
            honest_pool,
            num_honest,
            replace=False
        )
        print("clients: ", clients)

        global_model.eval()
        global_model = global_model.to(device)

        local_states = []

        # train honest clients
        for i, c in enumerate(clients):
            print("round {}, starting client {}/{}, id: {}".format(
                t, i + 1, num_clients_per_round, c
            ))
            local_model = train_client(
                c,
                client_train_loader[c],
                global_model,
                num_local_epochs,
                lr
            )
            local_states.append(local_model.state_dict())

        # train attacker (model poisoning)
        if modelPoisonAttack:
            print("Constrain and scale attack (attacker id {})".format(attacker_id))
            poisoned_local_model = train_poisoned_model(
                client_train_loader[attacker_id],
                global_model,
                num_local_epochs,
                lr
            )
            local_states.append(poisoned_local_model.state_dict())

        # defense vs no defense
        if defense == "median":
            print("Using coordinate-wise median defense")
            new_state = robust_aggregate_median(local_states)
        else:
            print("Using simple average aggregation")
            new_state = None
            scale = 1.0 / len(local_states)
            for s in local_states:
                new_state = running_model_avg(new_state, s, scale)
        global_model.load_state_dict(new_state)

        # Evaluate on test sett
        val_acc = validate(global_model, test_loader)
        print("round {}, test validation acc: {}".format(t, val_acc))
        round_accuracy.append(val_acc)

        if (t % 10 == 0):
            np.save(filename + "_{}".format(t) + ".npy", np.array(round_accuracy))

        # find backdoor success 
        poison_val_acc = validate_poisons(global_model, test_loader, target_class, base_class)
        print("round {}, poison validation acc: {}".format(t, poison_val_acc))
        poison_round_accuracy.append(poison_val_acc)

    return np.array(round_accuracy), np.array(poison_round_accuracy)

# %%
'''# model poisoning attack (i.e. calculate the ideal model to minimize poison loss and l2 dist from global model),
# or simple label-flip attack on data
def fed_avg_experiment(global_model, num_clients_per_round, num_local_epochs, lr, client_train_loader, max_rounds, filename, modelPoisonAttack=False, base_class=7, target_class=1):
    if modelPoisonAttack:
       print("Using constrain-and-scale attack + upsampling base class images")
    else:
       print("Using basic label flipping without modifying client images")
    round_accuracy = []
    poison_round_accuracy = []

    if modelPoisonAttack == False: #basic label flip
       # "poison" the train set
        poisonDataLoader([iid_client_train_loader[x] for x in range(0,6)], base_class, target_class, increaseFrequency=False)
        img, label = next(iter(iid_client_train_loader[0]))
        view_10(img, label)
    else:
        #reserve cllient 99 for this attack
        poisonDataLoader([client_train_loader[99]],base_class, target_class, increaseFrequency=True)
        img, label = next(iter(iid_client_train_loader[99]))
        view_10(img, label)

    for t in range(max_rounds):
        print("starting round {}".format(t))

        # choose clients
        clients = np.random.choice(np.arange(100-1), num_clients_per_round - (1 if modelPoisonAttack else 0), replace = False)
        print("clients: ", clients)

        global_model.eval()
        global_model = global_model.to(device)
        running_avg = None

        for i,c in enumerate(clients):
            # train local client
            print("round {}, starting client {}/{}, id: {}".format(t, i+1,num_clients_per_round, c))
            local_model = train_client(c, client_train_loader[c], global_model, num_local_epochs, lr)

            # add local model parameters to running average
            running_avg = running_model_avg(running_avg, local_model.state_dict(), 1.0/num_clients_per_round)
        
        if modelPoisonAttack:
          print("Constrain and scale attack")
          poisoned_local_model = train_poisoned_model(client_train_loader[99], global_model, num_local_epochs, lr)
          running_avg = running_model_avg(running_avg, poisoned_local_model.state_dict(), 1.0/num_clients_per_round)
        

        # set global model parameters for the next step
        global_model.load_state_dict(running_avg)

        # validate
        val_acc = validate(global_model, test_loader)
        print("round {}, test validation acc: {}".format(t, val_acc))
        round_accuracy.append(val_acc)

        if (t % 10 == 0):
          np.save(filename+'_{}'.format(t)+'.npy', np.array(round_accuracy))

        #test against poisons
        poison_val_acc = validate_poisons(global_model, test_loader, target_class, base_class)
        print("round {}, poison validation acc: {}".format(t, poison_val_acc))
        poison_round_accuracy.append(poison_val_acc)

    return np.array(round_accuracy), np.array(poison_round_accuracy)'''
# Out:
# '# model poisoning attack (i.e. calculate the ideal model to minimize poison loss and l2 dist from global model),\n# or simple label-flip attack on data\ndef fed_avg_experiment(global_model, num_clients_per_round, num_local_epochs, lr, client_train_loader, max_rounds, filename, modelPoisonAttack=False, base_class=7, target_class=1):\n    if modelPoisonAttack:\n       print("Using constrain-and-scale attack + upsampling base class images")\n    else:\n       print("Using basic label flipping without modifying client images")\n    round_accuracy = []\n    poison_round_accuracy = []\n\n    if modelPoisonAttack == False: #basic label flip\n       # "poison" the train set\n        poisonDataLoader([iid_client_train_loader[x] for x in range(0,6)], base_class, target_class, increaseFrequency=False)\n        img, label = next(iter(iid_client_train_loader[0]))\n        view_10(img, label)\n    else:\n        #reserve cllient 99 for this attack\n        poisonDataLoader([client_train_loader[99]],base_class, target_class, increaseFrequency=True)\n        img, label = next(iter(iid_client_train_loader[99]))\n        view_10(img, label)\n\n    for t in range(max_rounds):\n        print("starting round {}".format(t))\n\n        # choose clients\n        clients = np.random.choice(np.arange(100-1), num_clients_per_round - (1 if modelPoisonAttack else 0), replace = False)\n        print("clients: ", clients)\n\n        global_model.eval()\n        global_model = global_model.to(device)\n        running_avg = None\n\n        for i,c in enumerate(clients):\n            # train local client\n            print("round {}, starting client {}/{}, id: {}".format(t, i+1,num_clients_per_round, c))\n            local_model = train_client(c, client_train_loader[c], global_model, num_local_epochs, lr)\n\n            # add local model parameters to running average\n            running_avg = running_model_avg(running_avg, local_model.state_dict(), 1.0/num_clients_per_round)\n        \n        if modelPoisonAttack:\n          print("Constrain and scale attack")\n          poisoned_local_model = train_poisoned_model(client_train_loader[99], global_model, num_local_epochs, lr)\n          running_avg = running_model_avg(running_avg, poisoned_local_model.state_dict(), 1.0/num_clients_per_round)\n        \n\n        # set global model parameters for the next step\n        global_model.load_state_dict(running_avg)\n\n        # validate\n        val_acc = validate(global_model, test_loader)\n        print("round {}, test validation acc: {}".format(t, val_acc))\n        round_accuracy.append(val_acc)\n\n        if (t % 10 == 0):\n          np.save(filename+\'_{}\'.format(t)+\'.npy\', np.array(round_accuracy))\n\n        #test against poisons\n        poison_val_acc = validate_poisons(global_model, test_loader, target_class, base_class)\n        print("round {}, poison validation acc: {}".format(t, poison_val_acc))\n        poison_round_accuracy.append(poison_val_acc)\n\n    return np.array(round_accuracy), np.array(poison_round_accuracy)'

# %% [markdown]
# ## CNN Experiments

# %%
cnn = CNN()
print(cnn)
# print("total params: ", num_params(cnn))
# Out:
# CNN(
#   (conv1): Conv2d(1, 32, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1))
#   (fc): Linear(in_features=1024, out_features=512, bias=True)
#   (out): Linear(in_features=512, out_features=10, bias=True)
# )

# %%
# CNN - iid - m=10 experiment (label flip; toggle attack with modelPoisonAttack==True/False)
iid_client_train_loader = iid_partition_loader(train_data, bsz = bsz)
cnn_iid_m10 = copy.deepcopy(cnn)
acc_cnn_iid_m10, poison_acc_cnn_iid_m10 = fed_avg_experiment(cnn_iid_m10, num_clients_per_round=10, 
                                 num_local_epochs=5,
                                 lr=0.01,
                                 client_train_loader = iid_client_train_loader,
                                 max_rounds=10, # orig 100
                                 filename='./acc_cnn_iid_m10', modelPoisonAttack=False)
print("validation acc: ", acc_cnn_iid_m10)
print("poison validation acc: ", poison_acc_cnn_iid_m10)
# np.save('./acc_cnn_iid_m10.npy', acc_cnn_iid_m10)

"""
on original data (10 clients per round, 5 local epochs, lr 0.01, iid data, 10 rounds): 
global test accuracy per round: [0.9102 0.9339 0.9475 0.9568 0.9624 0.9643 0.9687 0.9712 0.9736 0.9736]


 >> simple label flipping (clients 0~5 have all their base class labels -> target class)
validation acc:  [0.8942 0.9307 0.9428 0.9553 0.9613 0.9656 0.969  0.9704 0.9726 0.9746]
poison validation acc:  [0.0311284  0.01750973 0.01070039 0.00972763 0.00875486 0.00680934
 0.00875486 0.0077821  0.00972763 0.00583658]
 """
# Out:
# Using basic label flipping without modifying client images
# starting round 0
# clients:  [26 86  2 55 75 92 16 73 54 94]
# round 0, starting client 1/10, id: 26
# round 0, starting client 2/10, id: 86
# round 0, starting client 3/10, id: 2
# round 0, starting client 4/10, id: 55
# round 0, starting client 5/10, id: 75
# round 0, starting client 6/10, id: 92
# round 0, starting client 7/10, id: 16
# round 0, starting client 8/10, id: 73
# round 0, starting client 9/10, id: 54
# round 0, starting client 10/10, id: 94
# round 0, test validation acc: 0.9011
# round 0, poison validation acc: 0.0311284046692607
# starting round 1
# clients:  [18 29 63 72 71 86  5 15 12 17]
# round 1, starting client 1/10, id: 18
# round 1, starting client 2/10, id: 29
# round 1, starting client 3/10, id: 63
# round 1, starting client 4/10, id: 72
# round 1, starting client 5/10, id: 71
# round 1, starting client 6/10, id: 86
# round 1, starting client 7/10, id: 5
# round 1, starting client 8/10, id: 15
# round 1, starting client 9/10, id: 12
# round 1, starting client 10/10, id: 17
# round 1, test validation acc: 0.9334
# round 1, poison validation acc: 0.01848249027237354
# starting round 2
# clients:  [66 42 57 13 71  4 81 14 56 91]
# round 2, starting client 1/10, id: 66
# round 2, starting client 2/10, id: 42
# round 2, starting client 3/10, id: 57
# round 2, starting client 4/10, id: 13
# round 2, starting client 5/10, id: 71
# round 2, starting client 6/10, id: 4
# round 2, starting client 7/10, id: 81
# round 2, starting client 8/10, id: 14
# round 2, starting client 9/10, id: 56
# round 2, starting client 10/10, id: 91
# round 2, test validation acc: 0.9466
# round 2, poison validation acc: 0.01264591439688716
# starting round 3
# clients:  [53 83 33 52  2 48 47 66 41 65]
# round 3, starting client 1/10, id: 53
# round 3, starting client 2/10, id: 83
# round 3, starting client 3/10, id: 33
# round 3, starting client 4/10, id: 52
# round 3, starting client 5/10, id: 2
# round 3, starting client 6/10, id: 48
# round 3, starting client 7/10, id: 47
# round 3, starting client 8/10, id: 66
# round 3, starting client 9/10, id: 41
# round 3, starting client 10/10, id: 65
# round 3, test validation acc: 0.9556
# round 3, poison validation acc: 0.010700389105058366
# starting round 4
# clients:  [62 55 44 52  2 66 13 15 89 37]
# round 4, starting client 1/10, id: 62
# round 4, starting client 2/10, id: 55
# round 4, starting client 3/10, id: 44
# round 4, starting client 4/10, id: 52
# round 4, starting client 5/10, id: 2
# round 4, starting client 6/10, id: 66
# round 4, starting client 7/10, id: 13
# round 4, starting client 8/10, id: 15
# round 4, starting client 9/10, id: 89
# round 4, starting client 10/10, id: 37
# round 4, test validation acc: 0.9593
# round 4, poison validation acc: 0.007782101167315175
# starting round 5
# clients:  [92 49 68 23  9 67 72 81 91 84]
# round 5, starting client 1/10, id: 92
# round 5, starting client 2/10, id: 49
# round 5, starting client 3/10, id: 68
# round 5, starting client 4/10, id: 23
# round 5, starting client 5/10, id: 9
# round 5, starting client 6/10, id: 67
# round 5, starting client 7/10, id: 72
# round 5, starting client 8/10, id: 81
# round 5, starting client 9/10, id: 91
# round 5, starting client 10/10, id: 84
# round 5, test validation acc: 0.9652
# round 5, poison validation acc: 0.008754863813229572
# starting round 6
# clients:  [92 22  6 28 79 93 39 11 76  2]
# round 6, starting client 1/10, id: 92
# round 6, starting client 2/10, id: 22
# round 6, starting client 3/10, id: 6
# round 6, starting client 4/10, id: 28
# round 6, starting client 5/10, id: 79
# round 6, starting client 6/10, id: 93
# round 6, starting client 7/10, id: 39
# round 6, starting client 8/10, id: 11
# round 6, starting client 9/10, id: 76
# round 6, starting client 10/10, id: 2
# round 6, test validation acc: 0.9679
# round 6, poison validation acc: 0.008754863813229572
# starting round 7
# clients:  [98  3  7 79 64 40 22 27 52 47]
# round 7, starting client 1/10, id: 98
# round 7, starting client 2/10, id: 3
# round 7, starting client 3/10, id: 7
# round 7, starting client 4/10, id: 79
# round 7, starting client 5/10, id: 64
# round 7, starting client 6/10, id: 40
# round 7, starting client 7/10, id: 22
# round 7, starting client 8/10, id: 27
# round 7, starting client 9/10, id: 52
# round 7, starting client 10/10, id: 47
# round 7, test validation acc: 0.9706
# round 7, poison validation acc: 0.006809338521400778
# starting round 8
# clients:  [ 2 15 72 21 89 91 41 45 51 88]
# round 8, starting client 1/10, id: 2
# round 8, starting client 2/10, id: 15
# round 8, starting client 3/10, id: 72
# round 8, starting client 4/10, id: 21
# round 8, starting client 5/10, id: 89
# round 8, starting client 6/10, id: 91
# round 8, starting client 7/10, id: 41
# round 8, starting client 8/10, id: 45
# round 8, starting client 9/10, id: 51
# round 8, starting client 10/10, id: 88
# round 8, test validation acc: 0.9726
# round 8, poison validation acc: 0.007782101167315175
# starting round 9
# clients:  [95 77 97 53 32 18 64 82 31 61]
# round 9, starting client 1/10, id: 95
# round 9, starting client 2/10, id: 77
# round 9, starting client 3/10, id: 97
# round 9, starting client 4/10, id: 53
# round 9, starting client 5/10, id: 32
# round 9, starting client 6/10, id: 18
# round 9, starting client 7/10, id: 64
# round 9, starting client 8/10, id: 82
# round 9, starting client 9/10, id: 31
# round 9, starting client 10/10, id: 61
# round 9, test validation acc: 0.9748
# round 9, poison validation acc: 0.005836575875486381
# validation acc:  [0.9011 0.9334 0.9466 0.9556 0.9593 0.9652 0.9679 0.9706 0.9726 0.9748]
# poison validation acc:  [0.0311284  0.01848249 0.01264591 0.01070039 0.0077821  0.00875486
#  0.00875486 0.00680934 0.0077821  0.00583658]
# '\non original data (10 clients per round, 5 local epochs, lr 0.01, iid data, 10 rounds): \nglobal test accuracy per round: [0.9102 0.9339 0.9475 0.9568 0.9624 0.9643 0.9687 0.9712 0.9736 0.9736]\n\n\n >> simple label flipping (clients 0~5 have all their base class labels -> target class)\nvalidation acc:  [0.8942 0.9307 0.9428 0.9553 0.9613 0.9656 0.969  0.9704 0.9726 0.9746]\npoison validation acc:  [0.0311284  0.01750973 0.01070039 0.00972763 0.00875486 0.00680934\n 0.00875486 0.0077821  0.00972763 0.00583658]\n '

# %%
plt.figure()
plt.plot(acc_cnn_iid_m10, label="Clean Accuracy")
plt.plot(poison_acc_cnn_iid_m10, label="Backdoor Success")
plt.xlabel("Round")
plt.ylabel("Accuracy")
plt.title("Clean vs Backdoor Accuracy over Rounds For Basic Label Flipping with 5% Compromised Clients")
plt.legend()
plt.show()

# %%
# CNN - iid - m=10 experiment (constrain-and-scale i.e. model poisoning)
iid_client_train_loader = iid_partition_loader(train_data, bsz = bsz)
cnn_iid_m10 = copy.deepcopy(cnn)
acc_cnn_iid_m10_model_p, poison_acc_cnn_iid_m10_model_p = fed_avg_experiment(cnn_iid_m10, num_clients_per_round=10, 
                                 num_local_epochs=5,
                                 lr=0.01,
                                 client_train_loader = iid_client_train_loader,
                                 max_rounds=7, # orig 100
                                 filename='./acc_cnn_iid_m10', modelPoisonAttack=True)
print("validation acc: ", acc_cnn_iid_m10_model_p)
print("poison validation acc: ", poison_acc_cnn_iid_m10_model_p)

"""
>> model poisoning (constrain-and-scale) (hardcode 1 bad client each round)  + scale
up frequency of base class images in bad clients
validation acc:  [0.8063 0.8939 0.8352 0.9519 0.8584 0.9616 0.8729 0.9705 0.894  0.9704]
poison validation acc:  [0.27431907 0.23151751 0.942607   0.03988327 0.93677043 0.03891051
 0.90758755 0.01264591 0.75291829 0.03404669]
 """
# Out:
# Using constrain-and-scale attack + upsampling base class images
# starting round 0
# clients:  [26 86  2 55 75 92 16 73 54]
# round 0, starting client 1/10, id: 26
# round 0, starting client 2/10, id: 86
# round 0, starting client 3/10, id: 2
# round 0, starting client 4/10, id: 55
# round 0, starting client 5/10, id: 75
# round 0, starting client 6/10, id: 92
# round 0, starting client 7/10, id: 16
# round 0, starting client 8/10, id: 73
# round 0, starting client 9/10, id: 54
# Constrain and scale attack (attacker id 99)
# Using simple average aggregation
# round 0, test validation acc: 0.8537
# round 0, poison validation acc: 0.23443579766536965
# starting round 1
# clients:  [18 29 63 72 71 86  5 15 12]
# round 1, starting client 1/10, id: 18
# round 1, starting client 2/10, id: 29
# round 1, starting client 3/10, id: 63
# round 1, starting client 4/10, id: 72
# round 1, starting client 5/10, id: 71
# round 1, starting client 6/10, id: 86
# round 1, starting client 7/10, id: 5
# round 1, starting client 8/10, id: 15
# round 1, starting client 9/10, id: 12
# Constrain and scale attack (attacker id 99)
# Using simple average aggregation
# round 1, test validation acc: 0.9137
# round 1, poison validation acc: 0.13424124513618677
# starting round 2
# clients:  [66 42 57 13 71  4 81 14 56]
# round 2, starting client 1/10, id: 66
# round 2, starting client 2/10, id: 42
# round 2, starting client 3/10, id: 57
# round 2, starting client 4/10, id: 13
# round 2, starting client 5/10, id: 71
# round 2, starting client 6/10, id: 4
# round 2, starting client 7/10, id: 81
# round 2, starting client 8/10, id: 14
# round 2, starting client 9/10, id: 56
# Constrain and scale attack (attacker id 99)
# Using simple average aggregation
# round 2, test validation acc: 0.9078
# round 2, poison validation acc: 0.3025291828793774
# starting round 3
# clients:  [53 83 33 52  2 48 47 66 41]
# round 3, starting client 1/10, id: 53
# round 3, starting client 2/10, id: 83
# round 3, starting client 3/10, id: 33
# round 3, starting client 4/10, id: 52
# round 3, starting client 5/10, id: 2
# round 3, starting client 6/10, id: 48
# round 3, starting client 7/10, id: 47
# round 3, starting client 8/10, id: 66
# round 3, starting client 9/10, id: 41
# Constrain and scale attack (attacker id 99)
# Using simple average aggregation
# round 3, test validation acc: 0.8613
# round 3, poison validation acc: 0.8550583657587548
# starting round 4
# clients:  [62 55 44 52  2 66 13 15 89]
# round 4, starting client 1/10, id: 62
# round 4, starting client 2/10, id: 55
# round 4, starting client 3/10, id: 44
# round 4, starting client 4/10, id: 52
# round 4, starting client 5/10, id: 2
# round 4, starting client 6/10, id: 66
# round 4, starting client 7/10, id: 13
# round 4, starting client 8/10, id: 15
# round 4, starting client 9/10, id: 89
# Constrain and scale attack (attacker id 99)
# Using simple average aggregation
# round 4, test validation acc: 0.9587
# round 4, poison validation acc: 0.03988326848249027
# starting round 5
# clients:  [92 49 68 23  9 67 72 81 91]
# round 5, starting client 1/10, id: 92
# round 5, starting client 2/10, id: 49
# round 5, starting client 3/10, id: 68
# round 5, starting client 4/10, id: 23
# round 5, starting client 5/10, id: 9
# round 5, starting client 6/10, id: 67
# round 5, starting client 7/10, id: 72
# round 5, starting client 8/10, id: 81
# round 5, starting client 9/10, id: 91
# Constrain and scale attack (attacker id 99)
# Using simple average aggregation
# round 5, test validation acc: 0.869
# round 5, poison validation acc: 0.9056420233463035
# starting round 6
# clients:  [92 22  6 28 79 93 39 11 76]
# round 6, starting client 1/10, id: 92
# round 6, starting client 2/10, id: 22
# round 6, starting client 3/10, id: 6
# round 6, starting client 4/10, id: 28
# round 6, starting client 5/10, id: 79
# round 6, starting client 6/10, id: 93
# round 6, starting client 7/10, id: 39
# round 6, starting client 8/10, id: 11
# round 6, starting client 9/10, id: 76
# Constrain and scale attack (attacker id 99)
# Using simple average aggregation
# round 6, test validation acc: 0.9646
# round 6, poison validation acc: 0.04182879377431906
# validation acc:  [0.8537 0.9137 0.9078 0.8613 0.9587 0.869  0.9646]
# poison validation acc:  [0.2344358  0.13424125 0.30252918 0.85505837 0.03988327 0.90564202
#  0.04182879]
# '\n>> model poisoning (constrain-and-scale) (hardcode 1 bad client each round)  + scale\nup frequency of base class images in bad clients\nvalidation acc:  [0.8063 0.8939 0.8352 0.9519 0.8584 0.9616 0.8729 0.9705 0.894  0.9704]\npoison validation acc:  [0.27431907 0.23151751 0.942607   0.03988327 0.93677043 0.03891051\n 0.90758755 0.01264591 0.75291829 0.03404669]\n '

# %%
# JUST ADDED
# CNN - iid - m=10 experiment WITH median defense (model poisoning)
iid_client_train_loader = iid_partition_loader(train_data, bsz = bsz)
cnn_iid_m10_def = copy.deepcopy(cnn)
acc_cnn_iid_m10_model_p_def, poison_acc_cnn_iid_m10_model_p_def = fed_avg_experiment(
    cnn_iid_m10_def,
    num_clients_per_round=10,
    num_local_epochs=5,
    lr=0.01,
    client_train_loader=iid_client_train_loader,
    max_rounds=7,  # keep same as no-defense run
    filename='./acc_cnn_iid_m10_median_def',
    modelPoisonAttack=True,
    defense="median"    # added median defense here
)
print("validation acc (defense): ", acc_cnn_iid_m10_model_p_def)
print("poison validation acc (defense): ", poison_acc_cnn_iid_m10_model_p_def)
# Out:
# Using constrain-and-scale attack + upsampling base class images
# starting round 0
# clients:  [98  3  7 79 64 40 22 27 52]
# round 0, starting client 1/10, id: 98
# round 0, starting client 2/10, id: 3
# round 0, starting client 3/10, id: 7
# round 0, starting client 4/10, id: 79
# round 0, starting client 5/10, id: 64
# round 0, starting client 6/10, id: 40
# round 0, starting client 7/10, id: 22
# round 0, starting client 8/10, id: 27
# round 0, starting client 9/10, id: 52
# Constrain and scale attack (attacker id 99)
# Using coordinate-wise median defense
# round 0, test validation acc: 0.8961
# round 0, poison validation acc: 0.08171206225680934
# starting round 1
# clients:  [ 2 15 72 21 89 91 41 45 51]
# round 1, starting client 1/10, id: 2
# round 1, starting client 2/10, id: 15
# round 1, starting client 3/10, id: 72
# round 1, starting client 4/10, id: 21
# round 1, starting client 5/10, id: 89
# round 1, starting client 6/10, id: 91
# round 1, starting client 7/10, id: 41
# round 1, starting client 8/10, id: 45
# round 1, starting client 9/10, id: 51
# Constrain and scale attack (attacker id 99)
# Using coordinate-wise median defense
# round 1, test validation acc: 0.9302
# round 1, poison validation acc: 0.026264591439688716
# starting round 2
# clients:  [95 77 97 53 32 18 64 82 31]
# round 2, starting client 1/10, id: 95
# round 2, starting client 2/10, id: 77
# round 2, starting client 3/10, id: 97
# round 2, starting client 4/10, id: 53
# round 2, starting client 5/10, id: 32
# round 2, starting client 6/10, id: 18
# round 2, starting client 7/10, id: 64
# round 2, starting client 8/10, id: 82
# round 2, starting client 9/10, id: 31
# Constrain and scale attack (attacker id 99)
# Using coordinate-wise median defense
# round 2, test validation acc: 0.9445
# round 2, poison validation acc: 0.017509727626459144
# starting round 3
# clients:  [56 84 58 30 69 70 44 81 92]
# round 3, starting client 1/10, id: 56
# round 3, starting client 2/10, id: 84
# round 3, starting client 3/10, id: 58
# round 3, starting client 4/10, id: 30
# round 3, starting client 5/10, id: 69
# round 3, starting client 6/10, id: 70
# round 3, starting client 7/10, id: 44
# round 3, starting client 8/10, id: 81
# round 3, starting client 9/10, id: 92
# Constrain and scale attack (attacker id 99)
# Using coordinate-wise median defense
# round 3, test validation acc: 0.9532
# round 3, poison validation acc: 0.02529182879377432
# starting round 4
# clients:  [68 61 81 97 19  1 12 25 58]
# round 4, starting client 1/10, id: 68
# round 4, starting client 2/10, id: 61
# round 4, starting client 3/10, id: 81
# round 4, starting client 4/10, id: 97
# round 4, starting client 5/10, id: 19
# round 4, starting client 6/10, id: 1
# round 4, starting client 7/10, id: 12
# round 4, starting client 8/10, id: 25
# round 4, starting client 9/10, id: 58
# Constrain and scale attack (attacker id 99)
# Using coordinate-wise median defense
# round 4, test validation acc: 0.9614
# round 4, poison validation acc: 0.019455252918287938
# starting round 5
# clients:  [18 15 62 73  8 25 11 52 43]
# round 5, starting client 1/10, id: 18
# round 5, starting client 2/10, id: 15
# round 5, starting client 3/10, id: 62
# round 5, starting client 4/10, id: 73
# round 5, starting client 5/10, id: 8
# round 5, starting client 6/10, id: 25
# round 5, starting client 7/10, id: 11
# round 5, starting client 8/10, id: 52
# round 5, starting client 9/10, id: 43
# Constrain and scale attack (attacker id 99)
# Using coordinate-wise median defense
# round 5, test validation acc: 0.9629
# round 5, poison validation acc: 0.020428015564202335
# starting round 6
# clients:  [78 62 86 58 31 68 14  6 47]
# round 6, starting client 1/10, id: 78
# round 6, starting client 2/10, id: 62
# round 6, starting client 3/10, id: 86
# round 6, starting client 4/10, id: 58
# round 6, starting client 5/10, id: 31
# round 6, starting client 6/10, id: 68
# round 6, starting client 7/10, id: 14
# round 6, starting client 8/10, id: 6
# round 6, starting client 9/10, id: 47
# Constrain and scale attack (attacker id 99)
# Using coordinate-wise median defense
# round 6, test validation acc: 0.9671
# round 6, poison validation acc: 0.020428015564202335
# validation acc (defense):  [0.8961 0.9302 0.9445 0.9532 0.9614 0.9629 0.9671]
# poison validation acc (defense):  [0.08171206 0.02626459 0.01750973 0.02529183 0.01945525 0.02042802
#  0.02042802]

# %%
#JUST ADDED
plt.figure()
# No defense
plt.plot(acc_cnn_iid_m10_model_p, label="Clean (no defense)")
plt.plot(poison_acc_cnn_iid_m10_model_p, label="Backdoor (no defense)")
# Median defense
plt.plot(acc_cnn_iid_m10_model_p_def, label="Clean (median defense)")
plt.plot(poison_acc_cnn_iid_m10_model_p_def, label="Backdoor (median defense)")
plt.xlabel("Round")
plt.ylabel("Accuracy")
plt.title("Clean vs Backdoor Accuracy - Constrain-and-Scale, With/Without Median Defense")
plt.legend()
plt.show()

# %%
'''plt.figure()
plt.plot(acc_cnn_iid_m10_model_p, label="Clean Accuracy")
plt.plot(poison_acc_cnn_iid_m10_model_p, label="Backdoor Success")
plt.xlabel("Round")
plt.ylabel("Accuracy")
plt.title("Clean vs Backdoor Accuracy over Rounds For Constrain-and-Scale with 1 Compromised Client Every Round")
plt.legend()
plt.show()

#Clearly some overfitting'''

# %%
# CNN - iid - m=50 experiment
cnn_iid_m50 = copy.deepcopy(cnn)
acc_cnn_iid_m50 = fed_avg_experiment(cnn_iid_m50, num_clients_per_round=50, 
                                 num_local_epochs=5,
                                 lr=0.01,
                                 client_train_loader = iid_client_train_loader,
                                 max_rounds=100,
                                 filename='./acc_cnn_iid_m50')
print(acc_cnn_iid_m50)
np.save('./acc_cnn_iid_m50.npy', acc_cnn_iid_m50)

# %%
# CNN - non-iid - m=10 experiment
cnn_noniid_m10 = copy.deepcopy(cnn)
acc_cnn_noniid_m10 = fed_avg_experiment(cnn_noniid_m10, num_clients_per_round=10, 
                                 num_local_epochs=5,
                                 lr=0.01,
                                 client_train_loader = noniid_client_train_loader,
                                 max_rounds=200,
                                 filename='./acc_cnn_noniid_m10')
print(acc_cnn_noniid_m10)
np.save('./acc_cnn_noniid_m10.npy', acc_cnn_noniid_m10)

# %%
# CNN - non-iid - m=50 experiment
cnn_noniid_m50 = copy.deepcopy(cnn)
acc_cnn_noniid_m50 = fed_avg_experiment(cnn_noniid_m50, num_clients_per_round=50, 
                                 num_local_epochs=5,
                                 lr=0.01,
                                 client_train_loader = noniid_client_train_loader,
                                 max_rounds=100,
                                 filename='./acc_cnn_noniid_m50')
print(acc_cnn_noniid_m50)
np.save('./acc_cnn_noniid_m50.npy', acc_cnn_noniid_m50)
